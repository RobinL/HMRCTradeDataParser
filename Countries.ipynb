# %%
import sys
reload(sys)  # Reload does the trick!
sys.setdefaultencoding('UTF8')

# %%
#Create table of countries and their ISO equivalents
import pandas as pd 
url = "https://www.uktradeinfo.com/CodesAndGuides/Documents/Country_alpha.xls"
df = pd.read_excel(url)
df
# Out:
#                              Country Name Alpha Code  Sequence Code  \
# 0                             Afghanistan         AF            660
# 1                                 Albania         AL             70
# 2                                 Algeria         DZ            208
# 3                          American Samoa         AS            830
# 4                                 Andorra         AD             43
# 5                                  Angola         AO            330
# 6                                Anguilla         AI            446
# 7                              Antarctica         AQ            891
# 8                     Antigua and Barbuda         AG            459
# 9                               Argentina         AR            528
# 10                                Armenia         AM             77
# 11                                  Aruba         AW            474
# 12                              Australia         AU            800
# 13                                Austria         AT             38
# 14                             Azerbaijan         AZ             78
# 15                                Bahamas         BS            453
# 16                                Bahrain         BH            640
# 17                             Bangladesh         BD            666
# 18                               Barbados         BB            469
# 19                                Belarus         BY             73
# 20                                Belgium         BE             17
# 21                                 Belize         BZ            421
# 22                                  Benin         BJ            284
# 23                                Bermuda         BM            413
# 24                                 Bhutan         BT            675
# 25                                Bolivia         BO            516
# 26       Bonaire, Sint Eustatius and Saba         BQ            475
# 27                     Bosnia-Herzegovina         BA             93
# 28                               Botswana         BW            391
# 29                          Bouvet Island         BV            892
# ..                                    ...        ...            ...
# 232                              Thailand         TH            680
# 233                           Timor-Leste         TL            699
# 234                                  Togo         TG            280
# 235                                 Tonga         TO            817
# 236                   Trinidad and Tobago         TT            472
# 237                               Tunisia         TN            212
# 238                                Turkey         TR             52
# 239                          Turkmenistan         TM             80
# 240              Turks and Caicos Islands         TC            454
# 241                                Tuvalu         TV            807
# 242                                Uganda         UG            350
# 243                               Ukraine         UA             72
# 244                  United Arab Emirates         AE            647
# 245                        United Kingdom         GB              6
# 246                         United States         US            400
# 247  United States Minor outlying islands         UM            832
# 248          United States Virgin Islands         VI            457
# 249                               Uruguay         UY            524
# 250                            Uzbekistan         UZ             81
# 251                               Vanuatu         VU            816
# 252                    Vatican City State         VA             45
# 253     Venezuela, Bolivarian Republic of         VE            484
# 254                               Vietnam         VN            690
# 255               Virgin Islands, British         VG            468
# 256         Virgin Islands, United States         VI            457
# 257                     Wallis and Futuna         WF            811
# 258                        Western Sahara         EH            206
# 259                                 Yemen         YE            653
# 260                                Zambia         ZM            378
# 261                              Zimbabwe         ZW            382
#
#                                               Comments
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                    Including Cabinda
# 6                                                  NaN
# 7    Territory south of 60 south latitude; not incl...
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13   Excluding the territories of Jungholz and Mitt...
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                     Often referred to as Belorussia
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25   Also referred to as Bolivia, Plurinational Sta...
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 232                                                NaN
# 233                                                NaN
# 234                                                NaN
# 235                                                NaN
# 236                                                NaN
# 237                                                NaN
# 238                                                NaN
# 239                                                NaN
# 240                                                NaN
# 241                                                NaN
# 242                                                NaN
# 243                                                NaN
# 244  Abu Dhabi, Dubai, Sharjah, Ajman, Umm al Qaiwa...
# 245  Great Britain, Northern Ireland, British Chann...
# 246                              Including Puerto Rico
# 247  Including Baker Island, Howland Island, Jarvis...
# 248                  See Virgin Islands, United States
# 249                                                NaN
# 250                                                NaN
# 251                                                NaN
# 252                                       See Holy See
# 253                     Often referred to as Venezuela
# 254                                                NaN
# 255                                                NaN
# 256                                                NaN
# 257                             Including Alofi Island
# 258                                                NaN
# 259               Formerly North Yemen and South Yemen
# 260                                                NaN
# 261                                                NaN
#
# [262 rows x 4 columns]

# %%
url = "http://blog.plsoucy.com/wp-content/uploads/2012/04/countries-20140629.csv"

df_iso = pd.read_csv(url)

# %%
df_iso
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-3-ee6fa8f38890> in <module>()
# ----> 1 df_iso
#
# C:\Users\Robin\Anaconda\lib\site-packages\IPython\core\displayhook.pyc in __call__(self, result)
#     236                 self.write_format_data(format_dict, md_dict)
#     237                 self.log_output(format_dict)
# --> 238             self.finish_displayhook()
#     239
#     240     def cull_cache(self):
#
# C:\Users\Robin\Anaconda\lib\site-packages\IPython\kernel\zmq\displayhook.pyc in finish_displayhook(self)
#      70         sys.stderr.flush()
#      71         if self.msg['content']['data']:
# ---> 72             self.session.send(self.pub_socket, self.msg, ident=self.topic)
#      73         self.msg = None
#      74
#
# C:\Users\Robin\Anaconda\lib\site-packages\IPython\kernel\zmq\session.pyc in send(self, stream, msg_or_type, content, parent, ident, buffers, track, header, metadata)
#     647         if self.adapt_version:
#     648             msg = adapt(msg, self.adapt_version)
# --> 649         to_send = self.serialize(msg, ident)
#     650         to_send.extend(buffers)
#     651         longest = max([ len(s) for s in to_send ])
#
# C:\Users\Robin\Anaconda\lib\site-packages\IPython\kernel\zmq\session.pyc in serialize(self, msg, ident)
#     551             content = self.none
#     552         elif isinstance(content, dict):
# --> 553             content = self.pack(content)
#     554         elif isinstance(content, bytes):
#     555             # content is already packed, as in a relayed message
#
# C:\Users\Robin\Anaconda\lib\site-packages\IPython\kernel\zmq\session.pyc in <lambda>(obj)
#      83 # disallow nan, because it's not actually valid JSON
#      84 json_packer = lambda obj: jsonapi.dumps(obj, default=date_default,
# ---> 85     ensure_ascii=False, allow_nan=False,
#      86 )
#      87 json_unpacker = lambda s: jsonapi.loads(s)
#
# C:\Users\Robin\Anaconda\lib\site-packages\zmq\utils\jsonapi.pyc in dumps(o, **kwargs)
#      38         kwargs['separators'] = (',', ':')
#      39
# ---> 40     s = jsonmod.dumps(o, **kwargs)
#      41
#      42     if isinstance(s, unicode):
#
# C:\Users\Robin\Anaconda\lib\json\__init__.pyc in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, encoding, default, sort_keys, **kw)
#     248         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     249         separators=separators, encoding=encoding, default=default,
# --> 250         sort_keys=sort_keys, **kw).encode(obj)
#     251
#     252
#
# C:\Users\Robin\Anaconda\lib\json\encoder.pyc in encode(self, o)
#     208         if not isinstance(chunks, (list, tuple)):
#     209             chunks = list(chunks)
# --> 210         return ''.join(chunks)
#     211
#     212     def iterencode(self, o, _one_shot=False):
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xef in position 800: ordinal not in range(128)
